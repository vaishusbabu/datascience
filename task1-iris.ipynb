# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishusbabu/datascience/blob/main/task1-iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lets Grow More**
#
# Task 1
#
# Name : Vaishnavi S Babu
#
# Data Science Internship ,LETSGROWMORE
#
# Iris Flower Classification ML Project
#
# **Description Of Task**: This particular ML project is usually referred to as the “Hello World” of Machine Learning. The iris flowers dataset contains numeric attributes, and it is perfect for beginners to learn about supervised ML algorithms, mainly how to load and handle data. Also, since this is a small dataset, it can easily fit in memory without requiring special transformations

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sklearn

# %%
col_name=['Sepal_len','Sepal_width','Petal_len','Petal_width','Species']
iris_ds=pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",names=col_name)
iris_ds.head()
# Out:
#    Sepal_len  Sepal_width  Petal_len  Petal_width      Species
# 0        5.1          3.5        1.4          0.2  Iris-setosa
# 1        4.9          3.0        1.4          0.2  Iris-setosa
# 2        4.7          3.2        1.3          0.2  Iris-setosa
# 3        4.6          3.1        1.5          0.2  Iris-setosa
# 4        5.0          3.6        1.4          0.2  Iris-setosa

# %%
iris_ds.tail()
# Out:
#      Sepal_len  Sepal_width  Petal_len  Petal_width         Species
# 145        6.7          3.0        5.2          2.3  Iris-virginica
# 146        6.3          2.5        5.0          1.9  Iris-virginica
# 147        6.5          3.0        5.2          2.0  Iris-virginica
# 148        6.2          3.4        5.4          2.3  Iris-virginica
# 149        5.9          3.0        5.1          1.8  Iris-virginica

# %%
iris_ds.describe()
# Out:
#         Sepal_len  Sepal_width   Petal_len  Petal_width
# count  150.000000   150.000000  150.000000   150.000000
# mean     5.843333     3.054000    3.758667     1.198667
# std      0.828066     0.433594    1.764420     0.763161
# min      4.300000     2.000000    1.000000     0.100000
# 25%      5.100000     2.800000    1.600000     0.300000
# 50%      5.800000     3.000000    4.350000     1.300000
# 75%      6.400000     3.300000    5.100000     1.800000
# max      7.900000     4.400000    6.900000     2.500000

# %%
iris_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sepal_len    150 non-null    float64
#  1   Sepal_width  150 non-null    float64
#  2   Petal_len    150 non-null    float64
#  3   Petal_width  150 non-null    float64
#  4   Species      150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_ds.shape
# Out:
# (150, 5)

# %%
iris_ds.isnull()
# Out:
#      Sepal_len  Sepal_width  Petal_len  Petal_width  Species
# 0        False        False      False        False    False
# 1        False        False      False        False    False
# 2        False        False      False        False    False
# 3        False        False      False        False    False
# 4        False        False      False        False    False
# ..         ...          ...        ...          ...      ...
# 145      False        False      False        False    False
# 146      False        False      False        False    False
# 147      False        False      False        False    False
# 148      False        False      False        False    False
# 149      False        False      False        False    False
#
# [150 rows x 5 columns]

# %%
iris_ds.dtypes
# Out:
# Sepal_len      float64
# Sepal_width    float64
# Petal_len      float64
# Petal_width    float64
# Species         object
# dtype: object

# %%
iris_ds.count
# Out:
# <bound method DataFrame.count of      Sepal_len  Sepal_width  Petal_len  Petal_width         Species
# 0          5.1          3.5        1.4          0.2     Iris-setosa
# 1          4.9          3.0        1.4          0.2     Iris-setosa
# 2          4.7          3.2        1.3          0.2     Iris-setosa
# 3          4.6          3.1        1.5          0.2     Iris-setosa
# 4          5.0          3.6        1.4          0.2     Iris-setosa
# ..         ...          ...        ...          ...             ...
# 145        6.7          3.0        5.2          2.3  Iris-virginica
# 146        6.3          2.5        5.0          1.9  Iris-virginica
# 147        6.5          3.0        5.2          2.0  Iris-virginica
# 148        6.2          3.4        5.4          2.3  Iris-virginica
# 149        5.9          3.0        5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
iris_ds.columns
# Out:
# Index(['Sepal_len', 'Sepal_width', 'Petal_len', 'Petal_width', 'Species'], dtype='object')

# %%
pd.DataFrame(iris_ds)
# Out:
#      Sepal_len  Sepal_width  Petal_len  Petal_width         Species
# 0          5.1          3.5        1.4          0.2     Iris-setosa
# 1          4.9          3.0        1.4          0.2     Iris-setosa
# 2          4.7          3.2        1.3          0.2     Iris-setosa
# 3          4.6          3.1        1.5          0.2     Iris-setosa
# 4          5.0          3.6        1.4          0.2     Iris-setosa
# ..         ...          ...        ...          ...             ...
# 145        6.7          3.0        5.2          2.3  Iris-virginica
# 146        6.3          2.5        5.0          1.9  Iris-virginica
# 147        6.5          3.0        5.2          2.0  Iris-virginica
# 148        6.2          3.4        5.4          2.3  Iris-virginica
# 149        5.9          3.0        5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris_ds.nunique()
# Out:
# Sepal_len      35
# Sepal_width    23
# Petal_len      43
# Petal_width    22
# Species         3
# dtype: int64

# %%
unique=iris_ds.Species.unique().tolist()
unique
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
species_count=iris_ds.Species.value_counts()
count=species_count.tolist()
species_count.to_frame()
# Out:
#                  Species
# Iris-versicolor       50
# Iris-virginica        50
# Iris-setosa           50

# %%
iris_ds.Species.value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
iris_ds.max()
# Out:
# Sepal_len                 7.9
# Sepal_width               4.4
# Petal_len                 6.9
# Petal_width               2.5
# Species        Iris-virginica
# dtype: object

# %%
iris_ds.min()
# Out:
# Sepal_len              4.3
# Sepal_width              2
# Petal_len                1
# Petal_width            0.1
# Species        Iris-setosa
# dtype: object

# %%
plt.pie(count,labels=unique,labeldistance=1,wedgeprops={'linewidth':5,'edgecolor':'white'},autopct="%.02f%%")
plt.title("Number of species with their count", fontsize=20)
plt.show()

# %%
plt.subplots(figsize=(7,7))
sns.scatterplot(x='Sepal_len',y='Sepal_width',data=iris_ds,hue='Species');
plt.show()

# %%
plt.subplots(figsize=(7,7))
sns.scatterplot(x='Petal_len',y='Petal_width',data=iris_ds,hue='Species');
plt.show()

# %%
plot=sns.pairplot(iris_ds,hue='Species',diag_kind='hist')
plot.fig.suptitle("Relation of All Feature with Each Other",y=1.2,fontsize=20)
plt.show()

# %%
iris_ds.hist(figsize=(8,7),color='green',edgecolor='black');
plt.show()

# %%
from sklearn import preprocessing

# %%
X=iris_ds.iloc[:,0:4]
X.head()
# Out:
#    Sepal_len  Sepal_width  Petal_len  Petal_width
# 0        5.1          3.5        1.4          0.2
# 1        4.9          3.0        1.4          0.2
# 2        4.7          3.2        1.3          0.2
# 3        4.6          3.1        1.5          0.2
# 4        5.0          3.6        1.4          0.2

# %%
Y=iris_ds['Species']
Y=Y.values
Y[0:5]
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa'], dtype=object)

# %%
std=preprocessing.StandardScaler()
X=std.fit_transform(X)
X[0:5]
# Out:
# array([[-0.90068117,  1.03205722, -1.3412724 , -1.31297673],
#        [-1.14301691, -0.1249576 , -1.3412724 , -1.31297673],
#        [-1.38535265,  0.33784833, -1.39813811, -1.31297673],
#        [-1.50652052,  0.10644536, -1.2844067 , -1.31297673],
#        [-1.02184904,  1.26346019, -1.3412724 , -1.31297673]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state = 1)

# %%
X_test.shape
# Out:
# (45, 4)

# %%
X_train.shape
# Out:
# (105, 4)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
lr = LogisticRegression()
knn = KNeighborsClassifier()
dt = DecisionTreeClassifier()

# %%
models = [lr, knn, dt]
scores = []

for model in models:
  model.fit(X_train, Y_train) # LogisticRegression.fit(X_train, y_train) # Fitting Support Vector Classifer to the Training set
  Y_pred = model.predict(X_test) #LogisticRegression.predict(X_test) # Predicting the Test set results
  scores.append(accuracy_score(Y_test, Y_pred)) # Accuracy on the Test set results  
  print("\n\nAccuracy of " + type(model).__name__ + " is", accuracy_score(Y_test, Y_pred))
  print("\nclassification Report:\n",classification_report(Y_test, Y_pred))
# Out:
# Accuracy of LogisticRegression is 0.9555555555555556
#
# classification Report:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       0.94      0.94      0.94        18
#  Iris-virginica       0.92      0.92      0.92        13
#
#        accuracy                           0.96        45
#       macro avg       0.96      0.96      0.96        45
#    weighted avg       0.96      0.96      0.96        45
#
#
#
# Accuracy of KNeighborsClassifier is 0.9555555555555556
#
# classification Report:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       0.94      0.94      0.94        18
#  Iris-virginica       0.92      0.92      0.92        13
#
#        accuracy                           0.96        45
#       macro avg       0.96      0.96      0.96        45
# ...

# %%
results = pd.DataFrame({'Models': ['Logistic Regression', 'K-Nearest Neighbors', 'Decision Tree'],'Accuracy': scores})

results = results.sort_values(by='Accuracy', ascending=False)
print(results)
# Out:
#                 Models  Accuracy
# 0  Logistic Regression  0.955556
# 1  K-Nearest Neighbors  0.955556
# 2        Decision Tree  0.955556
